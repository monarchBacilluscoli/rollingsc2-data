# %%
print("Hello, World!")

# %%
file = "./obj_record_test.txt"
f = open(file, mode='r')

# %%
for i in [1,2,3,4,5,6]:
    print(f.readline())

# %%
f.close()

# %%
f = open("./obj_record_test.txt")  

in_this_block = True;
block_count = 1;
current_block_count = 0;
block = ""
line = f.readline()
while line:
    if(line.find("//") != -1):
        current_block_count+=1
    if(current_block_count==block_count):
        # start the record
        block+=line
    line = f.readline()
print(block)


f_out = open("./1.txt",mode=x)
f_out.write(block)
f_out.close()

f.close()


#todo 首先将一个//之内的内容找出来
#todo 然后将start找出来
#todo 把start底下第一组没有空行的数据找出来

#todo 把以上内容输出出来先看看
# Out:
# // 3目标 + 新拥挤距离 + fix/priori/assemble
# start:
# Enemy Loss average: 	95.8	Enemy Loss best: 	195	My Team Loss average: 	170.64	My Team Loss best: 	45	 average: 	300	 best: 	300
# Enemy Loss average: 	99.9	Enemy Loss best: 	195	My Team Loss average: 	142.46	My Team Loss best: 	16	 average: 	300	 best: 	300
# Enemy Loss average: 	98.6	Enemy Loss best: 	195	My Team Loss average: 	130.58	My Team Loss best: 	16	 average: 	300	 best: 	300
# Enemy Loss average: 	98.6	Enemy Loss best: 	195	My Team Loss average: 	118.88	My Team Loss best: 	0	 average: 	300	 best: 	300
# Enemy Loss average: 	97.2	Enemy Loss best: 	195	My Team Loss average: 	108.92	My Team Loss best: 	0	 average: 	300	 best: 	300
# Enemy Loss average: 	100.7	Enemy Loss best: 	195	My Team Loss average: 	109.58	My Team Loss best: 	0	 average: 	300	 best: 	300
# Enemy Loss average: 	123.6	Enemy Loss best: 	255	My Team Loss average: 	114.48	My Team Loss best: 	0	 average: 	300	 best: 	300
# ...

# %%
print(block.count("start"))
